# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Files to Load - Population Data
population_2007 = "population data/2007.csv"
population_2008 = "population data/2008.csv"
population_2010_2016 = "population data/2010 - 2016.csv"

# Files to Load - Employment Data
employment_hays = "employment data/Hays_County.csv"
employment_travis = "employment data/Travis_County.csv"
employment_williamson = "employment data/Williamson_County.csv"

# Files to Load - Wage Data
wage_hays = "wage data/hays_wages_revised.csv"
wage_travis = "wage data/travis_wages_revised.csv"
wage_williamson = "wage data/williamson_wages_revised.csv"

# Files to Load - Hays Data
hays_gross_income_percent = "hays_data/hays_gross_income_percent.csv"
hays_gross_rent = "hays_data/hays_gross_rent.csv"
hays_housing_tenure = "hays_data/hays_housing_tenure.csv"
hays_housing_value = "hays_data/hays_housing_value.csv"
hays_income_percent_with_mortgage = "hays_data/hays_income_percent_with_mortgage.csv"
hays_income_percent_without_mortgage = "hays_data/hays_income_percent_without_mortgage.csv"
hays_monthly_costs_with_mortgage = "hays_data/hays_monthly_costs_with_mortgage.csv"
hays_monthly_costs_without_mortgage = "hays_data/hays_monthly_costs_without_mortgage.csv"
hays_total_housing_units = "hays_data/hays_total_housing_units.csv"
hays_year_moved_in = "hays_data/hays_year_householder_moved_into_unit.csv"

# Files to Load - Travis Data
travis_gross_rent_percent = "Travis_County_Data/Gross Rent.csv"
travis_gross_rent = "Travis_County_Data/Gross.csv"
travis_housing_tenure = "Travis_County_Data/Housing_Tenure.csv"
travis_mortgage = "Travis_County_Data/Mortage_Status.csv"
travis_occupancy = "Travis_County_Data/Occupancy.csv"
travis_income_percent = "Travis_County_Data/Selected_Monthly_Percent.csv"
travis_housing_value = "Travis_County_Data/Values.csv"
travis_year_moved_in = "Travis_County_Data/Years_Moved_in.csv"

# Files to Load - Williamson Data
williamson_gross_rent_percent = "williamson_GRAPI.csv"
williamson_gross_rent = "williamson_gross_rent.csv"
williamson_housing = "williamson_housing.csv"
williamson_mortage_status = "williamson_mortage_status.csv"
williamson_SMOCAPI = "williamson_SMOCAPI.csv"
williamson_tenure = "williamson_tenure.csv"
williamson_value = "williamson_value.csv"
williamson_year_built = "williamson_year_built.csv"

# %%
# Read the data
population_2007_data = pd.read_csv(population_2007)
population_2008_data = pd.read_csv(population_2008)
population_2010_2016_data = pd.read_csv(population_2010_2016)

employment_hays_data = pd.read_csv(employment_hays)
employment_travis_data = pd.read_csv(employment_travis)
employment_williamson_data = pd.read_csv(employment_williamson)

wage_hays_data = pd.read_csv(wage_hays)
wage_travis_data = pd.read_csv(wage_travis)
wage_williamson_data = pd.read_csv(wage_williamson)

hays_gross_income_percent_data = pd.read_csv(hays_gross_income_percent)
hays_gross_rent_data = pd.read_csv(hays_gross_rent)
hays_housing_tenure_data = pd.read_csv(hays_housing_tenure)
hays_housing_value_data = pd.read_csv(hays_housing_value)
hays_income_percent_with_mortgage_data = pd.read_csv(hays_income_percent_with_mortgage)
hays_income_percent_without_mortgage_data = pd.read_csv(hays_income_percent_without_mortgage)
hays_monthly_costs_with_mortgage_data = pd.read_csv(hays_monthly_costs_with_mortgage)
hays_monthly_costs_without_mortgage_data = pd.read_csv(hays_monthly_costs_without_mortgage)
hays_total_housing_units_data = pd.read_csv(hays_total_housing_units)
hays_year_moved_in_data = pd.read_csv(hays_year_moved_in)

travis_gross_rent_percent_data = pd.read_csv(travis_gross_rent_percent)
travis_gross_rent_data = pd.read_csv(travis_gross_rent)
travis_housing_tenure_data = pd.read_csv(travis_housing_tenure)
travis_mortgage_data = pd.read_csv(travis_mortgage)
travis_occupancy_data = pd.read_csv(travis_occupancy)
travis_income_percent_data = pd.read_csv(travis_income_percent)
travis_housing_value_data = pd.read_csv(travis_housing_value)
travis_year_moved_in_data = pd.read_csv(travis_year_moved_in)

# %%
employment_travis_data
# Out:
#    Year  Period ID  Period           Area Adjusted Labor Force Employment  \
# 0  2016          0  Annual  Travis County  Not Adj     678,367    657,085
# 1  2015          0  Annual  Travis County  Not Adj     653,628    632,174
# 2  2014          0  Annual  Travis County  Not Adj     643,420    617,152
# 3  2013          0  Annual  Travis County  Not Adj     630,677    599,088
# 4  2012          0  Annual  Travis County  Not Adj     612,264    578,608
# 5  2011          0  Annual  Travis County  Not Adj     594,040    556,184
# 6  2010          0  Annual  Travis County  Not Adj     575,630    536,660
# 7  2009          0  Annual  Travis County  Not Adj     547,413    510,814
# 8  2008          0  Annual  Travis County  Not Adj     536,895    514,368
# 9  2007          0  Annual  Travis County  Not Adj     528,962    510,019
#
#   Unemployment  Unemployment Rate
# 0       21,282                3.1
# 1       21,454                3.3
# 2       26,268                4.1
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-e968d7595499> in <module>()
# ----> 1 wage_hays_data
#
# NameError: name 'wage_hays_data' is not defined
